# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# # pandas data structure:
#      - pandas series object(series)
#         - single column data (one din data)
#     - pandas data frame object(DataFrame):
#         - multipule columns data (two din data)

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# # pandas series

# %%
marks = [89, 77, 69, 90, 88, 87, 76, 55, 46]

# %%
s1 = pd.Series(marks)

# %%
s1
# Out:
# 0    89
# 1    77
# 2    69
# 3    90
# 4    88
# 5    87
# 6    76
# 7    55
# 8    46
# dtype: int64

# %% [markdown]
# # component: index , values, dtype

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
s1.values
# Out:
# array([89, 77, 69, 90, 88, 87, 76, 55, 46])

# %%
s1.dtype
# Out:
# dtype('int64')

# %%
s1.size
# Out:
# 9

# %%
len(s1)
# Out:
# 9

# %% [raw]
# note: if we dont provide indices, series use defult intiger indices

# %%
value = [89, 77, 69, 90, 88]

# %%
subject = ["Math", "Phy", "Chem", "Eng", "Urdu"]
marks = pd.Series(value, index=subject)

# %%
marks
# Out:
# Math    89
# Phy     77
# Chem    69
# Eng     90
# Urdu    88
# dtype: int64

# %%
frt = pd.Series([5,4,6,7,3,8], index=["apple", "banana", "orenge", "Kivi", "Mango", "cherry"])

# %%
frt
# Out:
# apple     5
# banana    4
# orenge    6
# Kivi      7
# Mango     3
# cherry    8
# dtype: int64

# %% [raw]
# defult index : integer location
# string index : lables

# %%
frt.index
# Out:
# Index(['apple', 'banana', 'orenge', 'Kivi', 'Mango', 'cherry'], dtype='object')
