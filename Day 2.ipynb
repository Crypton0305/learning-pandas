# %%
import pandas as pd

# %% [markdown]
# # pandas Series

# %%
marks = [34,56,75,87, 98,87,76]

# %%
s1 = pd.Series(marks)

# %%
s1
# Out:
# 0    34
# 1    56
# 2    75
# 3    87
# 4    98
# 5    87
# 6    76
# dtype: int64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
s1.values
# Out:
# array([34, 56, 75, 87, 98, 87, 76])

# %%
s1.dtype
# Out:
# dtype('int64')

# %%
s1.size
# Out:
# 7

# %%
len(s1)
# Out:
# 7

# %%
subject = ["phy", "chem", "math", "urdu", "islamiyat", "eng", "pts"]

# %%
s2 = pd.Series(marks, index=subject)

# %%
s2
# Out:
# phy          34
# chem         56
# math         75
# urdu         87
# islamiyat    98
# eng          87
# pts          76
# dtype: int64

# %%
s2.index
# Out:
# Index(['phy', 'chem', 'math', 'urdu', 'islamiyat', 'eng', 'pts'], dtype='object')

# %% [markdown]
# # accesing data from Series

# %%
s2
# Out:
# phy          34
# chem         56
# math         75
# urdu         87
# islamiyat    98
# eng          87
# pts          76
# dtype: int64

# %%
s2[4]
# Out:
# C:\Users\SMIT\AppData\Local\Temp\ipykernel_19024\3737454092.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s2[4]
# np.int64(98)

# %%
s2[2:4]
# Out:
# math    75
# urdu    87
# dtype: int64

# %%
s2[::2]
# Out:
# phy          34
# math         75
# islamiyat    98
# pts          76
# dtype: int64

# %% [markdown]
# # with lables

# %%
s2["islamiyat"]
# Out:
# np.int64(98)

# %%
s2["math":"islamiyat"]
# Out:
# math         75
# urdu         87
# islamiyat    98
# dtype: int64

# %% [raw]
# series slice by index -1
# lables came all values

# %% [markdown]
# # series function

# %%
sales = pd.Series([200, 300, 450, 200, 500])

# %%
sales
# Out:
# 0    200
# 1    300
# 2    450
# 3    200
# 4    500
# dtype: int64

# %%
sales.unique()
# Out:
# array([200, 300, 450, 500])

# %%
sales.value_counts()
# Out:
# 200    2
# 300    1
# 450    1
# 500    1
# Name: count, dtype: int64

# %%
sales.head(2)
# Out:
# 0    200
# 1    300
# dtype: int64

# %%
sales.tail(2)
# Out:
# 3    200
# 4    500
# dtype: int64

# %%
sales.sample(3)
# Out:
# 2    450
# 4    500
# 0    200
# dtype: int64

# %%
sales.describe()
# Out:
# count      5.0000
# mean     330.0000
# std      139.6424
# min      200.0000
# 25%      200.0000
# 50%      300.0000
# 75%      450.0000
# max      500.0000
# dtype: float64

# %%
sales.min()
# Out:
# 200

# %%
sales.max()
# Out:
# 500

# %%
sales.sum()
# Out:
# np.int64(1650)

# %%
sales.mean()
# Out:
# np.float64(330.0)

# %%
sales.median()
# Out:
# 300.0

# %%
sales.std()
# Out:
# 139.64240043768942

# %%
sales.sort_values(ascending=False)
# Out:
# 4    500
# 2    450
# 1    300
# 0    200
# 3    200
# dtype: int64

# %% [markdown]
# # series queries
#  - operators
#  -
#  - <
#  - ==
#  - !=
# python and or
# pandas  &  |

# %%
sales
# Out:
# 0    200
# 1    300
# 2    450
# 3    200
# 4    500
# dtype: int64

# %%
sales[sales > 250]
# Out:
# 1    300
# 2    450
# 4    500
# dtype: int64

# %%
sales[sales < 450]
# Out:
# 0    200
# 1    300
# 3    200
# dtype: int64

# %%
sales[sales == 200]
# Out:
# 0    200
# 3    200
# dtype: int64

# %%
sales[(sales > 250) & (sales < 500)]
# Out:
# 1    300
# 2    450
# dtype: int64

# %%
sales
# Out:
# 0    200
# 1    300
# 2    450
# 3    200
# 4    500
# dtype: int64

# %%
sales[(sales > 350) | (sales == 200)]
# Out:
# 0    200
# 2    450
# 3    200
# 4    500
# dtype: int64
